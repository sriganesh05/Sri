# %% [markdown]
# <a href="https://colab.research.google.com/github/sriganesh05/Sri/blob/main/HHH_electronics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HHH ELECTRONICS & GADGETS**

# %% [markdown]
# ---
# # ***Tools that are imported in this project***
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np

# %% [markdown]
# ---
#
#
# # ***DATA IMPORTING***

# %% [markdown]
# ---
#
# # ***The datasets that have been used in this project***
#
# ### Here we have four datasets:
#
#
# *   dim_customer.csv
# *   dim_market(1).csv
# *  dim_product(1).csv
# *   fact_sales_monthly(1).csv
#
# ---

# %% [markdown]
# # **Reading the datasets one by one and defining them with a unique variables**
#
# ---

# %%
df_customer= pd.read_csv('/content/dim_customer.csv', encoding='ISO-8859-1')
df_market= pd.read_csv('/content/dim_market (1).csv')
df_product= pd.read_csv('/content/dim_product (1).csv',encoding='ISO-8859-1')
df_sales_monthly= pd.read_csv('/content/fact_sales_monthly (1).csv')

# %% [markdown]
# ---
#
#
# # ***DATA EXPLORING***
#
#
# ---

# %% [markdown]
# #***dim_customer.csv***

# %%
df_customer.head()
# Out:
#    customer_code         customer       market        platform      channel
# 0       80001019          Neptune        China  Brick & Mortar  Distributor
# 1       70003182    Atliq e Store    Indonesia      E-Commerce       Direct
# 2       70003181  AltiQ Exclusive    Indonesia  Brick & Mortar       Direct
# 3       70007198  AltiQ Exclusive  South Korea  Brick & Mortar       Direct
# 4       70007199    Atliq e Store  South Korea      E-Commerce       Direct

# %%
df_customer.shape
# Out:
# (189, 5)

# %%
df_customer.customer.unique()
# Out:
# array(['Neptune', 'Atliq e Store', 'AltiQ Exclusive', 'Sage', 'Leader',
#        'Synthetic', 'Novus', 'Zone', 'Taobao', 'Amazon',
#        'Acclaimed Stores', 'Expert', "Argos (Sainsbury's)", 'Sorefoz',
#        'Nomad Stores', 'Expression', 'Control', 'Surface Stores',
#        'Insight', 'Forward Stores', 'Digimarket', 'Electricalsocity',
#        'Sound', 'Logic Stores', 'Propel', 'Epic Stores', 'Fnac-Darty',
#        'Nova', 'Euronics', 'Atlas Stores', 'Electricalsquipo Stores',
#        'Integration Stores', 'Electricalsara Stores',
#        'Currys (Dixons Carphone)', 'Reliance Digital',
#        'Electricalslance Stores', 'Chiptec', 'Boulanger', 'UniEuro',
#        'Radio Popular', 'Elkjøp', 'Chip 7', 'Elite', 'All-Out',
#        'Info Stores', 'Electricalsbea Stores', 'Flawless Stores',
#        'walmart', 'Costco', 'Staples', 'Relief', 'Premium Stores',
#        'Saturn', 'Otto', 'Notebillig', 'Coolblue', 'Electricalslytical',
# ...

# %%
df_customer.market.unique()
# Out:
# array(['China', 'Indonesia', 'South Korea', 'Sweden', 'Pakistan',
#        'Bangladesh', 'Philiphines', 'Australia', 'Newzealand', 'Austria',
#        'Poland', 'Norway', 'Netherlands', 'Japan', 'France', 'Canada',
#        'Germany', 'United Kingdom', 'Spain', 'Italy', 'Portugal', 'USA',
#        'India'], dtype=object)

# %%
df_customer.platform.unique()
# Out:
# array(['Brick & Mortar', 'E-Commerce'], dtype=object)

# %%
df_customer.channel.unique()
# Out:
# array(['Distributor', 'Direct', 'Retailer'], dtype=object)

# %%
df_customer.customer.value_counts()
# Out:
# customer
# Amazon                   26
# Atliq e Store            22
# AltiQ Exclusive          16
# Expert                    5
# Euronics                  4
#                          ..
# Electricalsbea Stores     1
# All-Out                   1
# Insight                   1
# Nova                      1
# Atliq Exclusive           1
# Name: count, Length: 68, dtype: int64

# %%
customers_name=df_customer["customer"].value_counts()
fig1= px.bar(customers_name,x=customers_name.index,y=customers_name.values,color=customers_name.index)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_customer.market.value_counts()
# Out:
# market
# India             18
# USA               13
# United Kingdom    11
# Canada            11
# Japan             10
# Portugal          10
# Italy             10
# Spain             10
# Germany           10
# France             9
# Norway             8
# Austria            8
# Netherlands        7
# Poland             7
# Newzealand         7
# Australia          7
# Philiphines        6
# Bangladesh         5
# Pakistan           5
# Sweden             5
# South Korea        5
# Indonesia          4
# China              3
# Name: count, dtype: int64

# %%
market_name=df_customer['market'].value_counts()
fig2=px.bar(market_name,x=market_name.index,y=market_name.values,color=market_name.index)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_customer.platform.value_counts()
# Out:
# platform
# Brick & Mortar    135
# E-Commerce         54
# Name: count, dtype: int64

# %%
platform_name=df_customer['platform'].value_counts()
fig3=px.bar(platform_name,x=platform_name.index,y=platform_name.values,color=platform_name.index)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_customer.channel.value_counts()
# Out:
# channel
# Retailer       146
# Direct          38
# Distributor      5
# Name: count, dtype: int64

# %%
channel_name=df_customer['channel'].value_counts()
fig4=px.bar(channel_name,x=channel_name.index,y=channel_name.values,color=channel_name.index)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #***dim_market.csv***

# %%
df_market.head()
# Out:
#            market sub_zone region
# 0          Canada      NaN    NaN
# 1             USA      NaN    NaN
# 2  United Kingdom       NE     EU
# 3         Austria       NE     EU
# 4          Sweden       NE     EU

# %%
df_market.shape
# Out:
# (23, 3)

# %%
df_market.market.unique()
# Out:
# array(['Canada', 'USA', 'United Kingdom', 'Austria', 'Sweden', 'Spain',
#        'Portugal', 'Poland', 'Norway', 'Netherlands', 'Italy', 'Germany',
#        'France', 'Bangladesh', 'Newzealand', 'Australia', 'South Korea',
#        'Philiphines', 'Pakistan', 'Japan', 'Indonesia', 'India', 'China'],
#       dtype=object)

# %%
df_market.sub_zone.unique()
# Out:
# array([nan, 'NE', 'SE', 'ROA', 'ANZ', 'India'], dtype=object)

# %%
df_market.region.unique()
# Out:
# array([nan, 'EU', 'APAC'], dtype=object)

# %%
df_market.market.value_counts()
# Out:
# market
# Canada            1
# France            1
# India             1
# Indonesia         1
# Japan             1
# Pakistan          1
# Philiphines       1
# South Korea       1
# Australia         1
# Newzealand        1
# Bangladesh        1
# Germany           1
# USA               1
# Italy             1
# Netherlands       1
# Norway            1
# Poland            1
# Portugal          1
# Spain             1
# Sweden            1
# Austria           1
# United Kingdom    1
# China             1
# Name: count, dtype: int64

# %%
df_market.sub_zone.value_counts()
# Out:
# sub_zone
# NE       7
# ROA      7
# SE       4
# ANZ      2
# India    1
# Name: count, dtype: int64

# %%
sub_zone=df_market['sub_zone'].value_counts()
fig5=px.bar(sub_zone,x=sub_zone.index,y=sub_zone.values,color=sub_zone.index)
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_market.region.value_counts()
# Out:
# region
# EU      11
# APAC    10
# Name: count, dtype: int64

# %%
region=df_market['region'].value_counts()
fig6=px.bar(region,x=region.index,y=region.values,color=region.index)
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #***dim_product.csv***

# %%
df_product.head()
# Out:
#   product_code division   segment       category     product  \
# 0  A5721110508       PC  Notebook  Gaming Laptop  AQ Smash 2
# 1  A5721110507       PC  Notebook  Gaming Laptop  AQ Smash 2
# 2  A5721110505       PC  Notebook  Gaming Laptop  AQ Smash 2
# 3  A5721110504       PC  Notebook  Gaming Laptop  AQ Smash 2
# 4  A5721110503       PC  Notebook  Gaming Laptop  AQ Smash 2
#
#                variant
# 0  Premium Misty Green
# 1        Premium Black
# 2       Plus Cool Blue
# 3       Plus Firey Red
# 4       Standard Black

# %%
df_product.shape
# Out:
# (298, 6)

# %%
df_product.division.unique()
# Out:
# array(['PC', 'N & S', 'P & A'], dtype=object)

# %%
df_product.segment.unique()
# Out:
# array(['Notebook', 'Networking', 'Storage', 'Desktop', 'Peripherals',
#        'Accessories'], dtype=object)

# %%
df_product.category.unique()
# Out:
# array(['Gaming Laptop', 'Personal Laptop', 'Wi fi extender',
#        'USB Flash Drives', 'External Solid State Drives',
#        'Personal Desktop', 'MotherBoard', 'Processors', 'Graphic Card',
#        'Internal HDD', 'Batteries', 'Keyboard', 'Mouse'], dtype=object)

# %%
df_product.variant.unique()
# Out:
# array(['Premium Misty Green', 'Premium Black', 'Plus Cool Blue',
#        'Plus Firey Red', 'Standard Black', 'Standard Cool Blue',
#        'Standard Firey Red', 'Plus Red', 'Plus Blue', 'Plus Grey',
#        'Standard Blue', 'Standard Grey', 'Premium', 'Plus', 'Standard',
#        'Premium 2', 'Premium 1', 'Plus 2', 'Standard 3', 'Standard 2',
#        'Standard 1', 'Premium Plus'], dtype=object)

# %%
unique=df_product['product'].unique()
unique
# Out:
# array(['AQ Smash 2', 'AQ Smash 1', 'AQ Gamer 3', 'AQ Gamer 2',
#        'AQ Gamer 1', 'AQ F16', 'AQ GEN Z', 'AQ Gen Y', 'AQ Gen X',
#        'AQ Elite', 'AQ Velocity', 'AQ Digit', 'AQ Aspiron',
#        'AQ Wi Power Dx3', 'AQ Wi Power Dx2', 'AQ Wi Power Dx1',
#        'AQ Ultra Dual 3.0', 'AQ Ultra Dual 2.0', 'AQ Pen Drive DRC',
#        'AQ Pen Drive 2 IN 1', 'AQ Clx3', 'AQ Clx2', 'AQ Clx1',
#        'AQ Neuer SSD', 'AQ Digit SSD', 'AQ HOME Allin1 Gen 2',
#        'AQ Home Allin1', 'AQ MB Lito 2', 'AQ MB Lito', 'AQ MB Crossx 2',
#        'AQ MB Crossx', 'AQ MB Elite',
#        'AQ Electron 3 3600 Desktop Processor',
#        'AQ Electron 4 3600 Desktop Processor',
#        'AQ Electron 5 3600 Desktop Processor',
#        'AQ 5000 Series Ultron 8 5900X Desktop Processor',
#        'AQ 5000 Series Electron 8 5900X Desktop Processor',
#        'AQ 5000 Series Electron 9 5900X Desktop Processor',
#        'AQ Marquee P4', 'AQ Marquee P3', 'AQ GT 21', 'AQ Mforce Gen Z',
# ...

# %%
df_product.division.value_counts()
# Out:
# division
# P & A    162
# PC       100
# N & S     36
# Name: count, dtype: int64

# %%
division=df_product['division'].value_counts()
fig7=px.bar(division,x=division.index,y=division.values,color=division.index)
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_product.segment.value_counts()
# Out:
# segment
# Accessories    92
# Notebook       88
# Peripherals    70
# Storage        27
# Desktop        12
# Networking      9
# Name: count, dtype: int64

# %%
segment=df_product['segment'].value_counts()
fig8=px.bar(segment,x=segment.index,y=segment.values,color=segment.index)
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_product.category.value_counts()
# Out:
# category
# Personal Laptop                53
# Keyboard                       40
# Mouse                          40
# Gaming Laptop                  35
# Graphic Card                   27
# Processors                     18
# External Solid State Drives    15
# MotherBoard                    15
# USB Flash Drives               12
# Personal Desktop               12
# Batteries                      12
# Internal HDD                   10
# Wi fi extender                  9
# Name: count, dtype: int64

# %%
category=df_product['category'].value_counts()
fig9=px.bar(category,x=category.index,y=category.values,color=category.index)
fig9.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_product.variant.value_counts()
# Out:
# variant
# Plus 2                 33
# Standard               33
# Premium                33
# Standard 1             21
# Standard 2             21
# Premium 1              21
# Premium 2              21
# Plus                   21
# Premium Black          12
# Premium Misty Green    11
# Standard Grey           8
# Standard Blue           8
# Plus Grey               8
# Plus Blue               8
# Plus Red                8
# Standard Firey Red      5
# Standard Cool Blue      5
# Standard Black          5
# Standard 3              5
# Plus Firey Red          5
# Plus Cool Blue          5
# Premium Plus            1
# Name: count, dtype: int64

# %%
variant=df_product['variant'].value_counts()
fig10=px.bar(variant,x=variant.index,y=variant.values,color=variant.index)
fig10.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #***fact_sales_monthly.csv***

# %%
df_sales_monthly.head()
# Out:
#                date product_code  customer_code  Qty  net_sales_amount
# 0  01-09-2018 00:00  A0418150108       90023030  -16            163.98
# 1  01-09-2018 00:00  A3019150205       90023023  132            698.85
# 2  01-09-2018 00:00  A3019150205       90023030  111            641.68
# 3  01-09-2018 00:00  A3019150205       90012041  -59            289.60
# 4  01-09-2018 00:00  A3019150205       90014141    4             19.95

# %%
df_sales_monthly.shape
# Out:
# (799962, 5)

# %%
df_sales_monthly.describe()
# Out:
#        customer_code            Qty  net_sales_amount
# count   7.999620e+05  799962.000000     799962.000000
# mean    8.563803e+07      50.632374       1103.860317
# std     8.079951e+06     201.821364       1989.152675
# min     7.000202e+07   -5788.000000          1.060000
# 25%     9.000200e+07       1.000000        179.210000
# 50%     9.001118e+07       9.000000        450.665000
# 75%     9.001810e+07      54.000000       1164.430000
# max     9.002303e+07    5832.000000      54453.020000

# %% [markdown]
# #**DATA CLEANING**

# %% [markdown]
# # **dim_customer.csv**

# %%
df_customer.isna().sum()
# Out:
# customer_code    0
# customer         0
# market           0
# platform         0
# channel          0
# dtype: int64

# %%
df_customer.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are no missing values and duplicate values in this dataframe

# %% [markdown]
# # dim_market.**csv**

# %%
df_market.isna().sum()
# Out:
# market      0
# sub_zone    2
# region      2
# dtype: int64

# %% [markdown]
# here we can see two values are missing from sub_zone & two from region

# %%
df_market['sub_zone'].fillna('unknown',inplace=True)
df_market['region'].fillna('unknown',inplace=True)

# %%
df_market.isna().sum()
# Out:
# market      0
# sub_zone    0
# region      0
# dtype: int64

# %%
df_market.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are no missing values and duplicate values
#
# ---

# %% [markdown]
# # dim_product.***csv*** italicized text

# %%
df_product.isna().sum()
# Out:
# product_code    0
# division        0
# segment         0
# category        0
# product         0
# variant         0
# dtype: int64

# %%
df_product.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are no missing values and duplicate values
#
# ---

# %% [markdown]
# # fact_sales_monthly.**csv**

# %%
df_sales_monthly.isna().sum()
# Out:
# date                0
# product_code        1
# customer_code       1
# Qty                 1
# net_sales_amount    1
# dtype: int64

# %% [markdown]
# one missing values take place in product_code,customer_code, Qty and net_sales_amount

# %%
df_sales_monthly['product_code'].fillna('unknown',inplace=True)
df_sales_monthly['customer_code'].fillna('unknown',inplace=True)
df_sales_monthly['Qty'].fillna('Na',inplace=True)
df_sales_monthly['net_sales_amount'].fillna('Na',inplace=True)
# Out:
# <ipython-input-4-511249c3f630>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sales_monthly['product_code'].fillna('unknown',inplace=True)
# <ipython-input-4-511249c3f630>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_sales_monthly.isna().sum()
# Out:
# date                0
# product_code        0
# customer_code       0
# Qty                 0
# net_sales_amount    0
# dtype: int64

# %%
df_sales_monthly.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are no missing values and duplicate values
#
# ---

# %% [markdown]
# # **Handle Outliers**

# %%
df_sales_monthly
# Out:
#                     date product_code  customer_code  Qty  net_sales_amount
# 0       01-09-2018 00:00  A0418150108       90023030  -16            163.98
# 1       01-09-2018 00:00  A3019150205       90023023  132            698.85
# 2       01-09-2018 00:00  A3019150205       90023030  111            641.68
# 3       01-09-2018 00:00  A3019150205       90012041  -59            289.60
# 4       01-09-2018 00:00  A3019150205       90014141    4             19.95
# ...                  ...          ...            ...  ...               ...
# 799957  01-08-2021 00:00  A3019150205       70017060   37            260.80
# 799958  01-08-2021 00:00  A3019150205       70007199   66            390.05
# 799959  01-08-2021 00:00  A3019150205       70018115  101            507.93
# 799960  01-08-2021 00:00  A3019150205       70019204   20            129.95
# 799961  01-08-2021 00:00  A3019150205       70021096 -200           1324.23
#
# [799962 rows x 5 columns]

# %%
df_sales_monthly.head()
# Out:
#                date product_code  customer_code  Qty  net_sales_amount
# 0  01-09-2018 00:00  A0418150108       90023030  -16            163.98
# 1  01-09-2018 00:00  A3019150205       90023023  132            698.85
# 2  01-09-2018 00:00  A3019150205       90023030  111            641.68
# 3  01-09-2018 00:00  A3019150205       90012041  -59            289.60
# 4  01-09-2018 00:00  A3019150205       90014141    4             19.95

# %%
df_sales_monthly.describe()
# Out:
#        customer_code           Qty  net_sales_amount
# count   8.603900e+04  86039.000000      86039.000000
# mean    8.580905e+07     69.724695        674.113701
# std     7.913234e+06    167.226796       1490.097763
# min     7.000202e+07      1.000000          1.390000
# 25%     9.000200e+07      2.000000        103.260000
# 50%     9.001118e+07     12.000000        266.000000
# 75%     9.001706e+07     60.000000        657.130000
# max     9.002303e+07   3919.000000      49839.600000

# %% [markdown]
# **As we see there are negative values on Qty column. They are inappropriate to the dataset. So we need to delete those values from the dataset**

# %%
df_sales_monthly[df_sales_monthly.Qty<0]
# Out:
#                     date product_code  customer_code  Qty  net_sales_amount
# 0       01-09-2018 00:00  A0418150108       90023030  -16            163.98
# 3       01-09-2018 00:00  A3019150205       90012041  -59            289.60
# 5       01-09-2018 00:00  A3019150205       90005162   -8             41.78
# 6       01-09-2018 00:00  A3019150205       90017059  -19             95.54
# 7       01-09-2018 00:00  A3019150205       90007197 -286           1758.71
# ...                  ...          ...            ...  ...               ...
# 799920  01-08-2021 00:00  A3019150206       70008170 -280           1554.46
# 799934  01-08-2021 00:00  A3019150206       70006158 -155           1066.66
# 799943  01-08-2021 00:00  A3019150205       70010048  -30            175.07
# 799955  01-08-2021 00:00  A3019150205       70006158 -158            918.60
# 799961  01-08-2021 00:00  A3019150205       70021096 -200           1324.23
#
# [160171 rows x 5 columns]

# %%
df_sales_monthly.drop(df_sales_monthly[df_sales_monthly["Qty"] < 0].index, inplace=True)

df_sales_monthly
# Out:
#                     date product_code  customer_code  Qty  net_sales_amount
# 1       01-09-2018 00:00  A3019150205       90023023  132            698.85
# 2       01-09-2018 00:00  A3019150205       90023030  111            641.68
# 4       01-09-2018 00:00  A3019150205       90014141    4             19.95
# 8       01-09-2018 00:00  A3019150205       90019203    1              4.51
# 9       01-09-2018 00:00  A3019150205       90021095   28            145.87
# ...                  ...          ...            ...  ...               ...
# 799956  01-08-2021 00:00  A3019150205       70016178   12             78.47
# 799957  01-08-2021 00:00  A3019150205       70017060   37            260.80
# 799958  01-08-2021 00:00  A3019150205       70007199   66            390.05
# 799959  01-08-2021 00:00  A3019150205       70018115  101            507.93
# 799960  01-08-2021 00:00  A3019150205       70019204   20            129.95
#
# [639791 rows x 5 columns]

# %% [markdown]
# # **Removing Outliers**

# %%
def remove_outliers(df_sales_monthly, net_sales_amount):
    Q1 = df_sales_monthly[net_sales_amount].quantile(0.25)
    Q3 = df_sales_monthly[net_sales_amount].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_filtered = df_sales_monthly[(df_sales_monthly[net_sales_amount] >= lower_bound) & (df_sales_monthly[net_sales_amount] <= upper_bound)]

    return df_filtered

df_sales_monthly_cleaned = remove_outliers(df_sales_monthly, 'net_sales_amount')

df_sales_monthly_cleaned.to_csv("fact_sales_monthly_cleaned.csv", index=False)

print("Outliers removed. Cleaned dataset saved as 'fact_sales_monthly_cleaned.csv'.")
# Out:
# Outliers removed. Cleaned dataset saved as 'fact_sales_monthly_cleaned.csv'.

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# First we need to convert 'date' column to date time format

# %%
df_sales_monthly_cleaned["date"] = pd.to_datetime(df_sales_monthly_cleaned["date"])
# Out:
# <ipython-input-8-796cf3c16374>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sales_monthly_cleaned["date"] = pd.to_datetime(df_sales_monthly_cleaned["date"])

# %%
df_sales_monthly_cleaned['year'] = df_sales_monthly_cleaned['date'].dt.year
yearly_sales = df_sales_monthly_cleaned.groupby('year')['net_sales_amount'].sum()
# Out:
# <ipython-input-21-38bb5cff723e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sales_monthly_cleaned['year'] = df_sales_monthly_cleaned['date'].dt.year

# %%
yearly_sales = df_sales_monthly_cleaned.groupby(["year"])["net_sales_amount"].sum().reset_index()
yearly_sales
# Out:
#    year  net_sales_amount
# 0  2018      1.641021e+07
# 1  2019      6.596120e+07
# 2  2020      1.233133e+08
# 3  2021      1.210750e+08

# %%
plt.figure(figsize=(10, 5))
plt.bar(yearly_sales['year'], yearly_sales['net_sales_amount'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Net Sales Amount')
plt.title('Yearly Total Net Sales')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # **Top 10 Products**

# %%
df_sales_monthly_cleaned['date'] = pd.to_datetime(df_sales_monthly_cleaned['date'], dayfirst=True, errors='coerce')
# Out:
# <ipython-input-7-e7b9903de6ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sales_monthly_cleaned['date'] = pd.to_datetime(df_sales_monthly_cleaned['date'], dayfirst=True, errors='coerce')

# %%
product_sales = df_sales_monthly_cleaned.groupby('product_code')['net_sales_amount'].sum().sort_values(ascending=False)
product_sales
# Out:
# product_code
# A6319160203    2400741.02
# A7118160101    2396998.35
# A7119160102    2393425.29
# A7219160201    2376190.51
# A7119160103    2365766.88
#                   ...
# A3819150203     238060.83
# A3718150105     228036.03
# A3718150103     222963.90
# A3818150201     222947.41
# A3718150101     215806.09
# Name: net_sales_amount, Length: 260, dtype: float64

# %%
plt.figure(figsize=(12, 6))
product_sales.head(10).plot(kind='line', color='skyblue')
plt.xlabel('Product Code')
plt.ylabel('Total Net Sales Amount')
plt.title('Top 10 Products by Total Net Sales')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # **Top 10 Customers**

# %%
top_customers = df_sales_monthly_cleaned.groupby('customer_code')['net_sales_amount'].sum().sort_values(ascending=False)
top_customers
# Out:
# customer_code
# 70007199    3122385.06
# 90007197    3087481.26
# 70007198    3009439.67
# 90022082    2995836.55
# 70003182    2936477.86
#                ...
# 90020100     293748.35
# 90020097     286219.36
# 90019201     285086.70
# 90020099     282011.54
# 90020098     262533.55
# Name: net_sales_amount, Length: 189, dtype: float64

# %%
plt.figure(figsize=(12, 6))
top_customers.head(10).plot(kind='bar', color='skyblue')
plt.xlabel('customer_code')
plt.ylabel('Total Net Sales Amount')
plt.title('Top 10 Customers by Total Net Sales')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## **Top 5 products which contributed the most on revenue**

# %%
product_sales = df_sales_monthly_cleaned.groupby('product_code')['net_sales_amount'].sum()
top_products = product_sales.nlargest(5)
top_products
# Out:
# product_code
# A7118160101    2522185.48
# A6319160203    2492497.88
# A7119160102    2479843.24
# A7219160201    2479340.67
# A1118150202    2464004.22
# Name: net_sales_amount, dtype: float64

# %%
plt.figure(figsize=(8, 8))
plt.pie(top_products, labels=top_products.index, autopct='%1.1f%%',
        startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])
plt.title("Top 5 Products by Sales")
plt.axis('equal')
plt.show()

# %% [markdown]
# # **Correlation**

# %%
correlation_matrix = df_sales_monthly_cleaned[['customer_code', 'Qty', 'net_sales_amount']].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', linewidths=0.5, fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # **Sales Distribution**

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_sales_monthly_cleaned['net_sales_amount'], bins=50, kde=True, color='skyblue')
plt.xlabel('Net Sales Amount')
plt.ylabel('Frequency')
plt.title('Sales Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
